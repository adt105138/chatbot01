# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import jieba
import numpy as np
from collections import Counter

text = open('two.txt', "r",encoding="utf-8").read()  #讀文字資料
 
jieba.set_dictionary('dictionary/dict.txt.big.txt')
with open('dictionary/stopword.txt', 'r', encoding='utf-8-sig') as f:  #設定停用詞
#with open('dictionary/stopWord_cloudmod.txt', 'r', encoding='utf-8-sig') as f:  #設定停用詞
    stops = f.read().split('\n')   
terms = []  #儲存字詞
for t in jieba.cut(text, cut_all=False):  #拆解句子為字詞
    if t not in stops:  #不是停用詞
        terms.append(t)
diction = Counter(terms)
# 可列印詞的統計數量
print(diction)

#font = "/Users/hongyining/Library/Fonts/Kaiu.ttf"  #設定字型(宋體)
font = "/System/Library/Fonts/PingFang.ttc"  #設定字型(宋體)
#wordcloud = WordCloud(font_path="C:\\Windows\\Fonts\\simsun.ttc")

#mask = np.array(Image.open("heart.png"))  #設定文字雲形狀 
#wordcloud = WordCloud(font_path=font) 
wordcloud = WordCloud(background_color="white",width=1000, height=860, margin=2, font_path=font)  #背景顏色預設黑色,改為白色,字體為宋體
wordcloud.generate_from_frequencies(diction)  #產生文字雲

#產生圖片
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

wordcloud.to_file("/Users/hongyining/testbot/static/two2.png")  #存檔
# Out:
# Building prefix dict from /Users/hongyining/testbot/dictionary/dict.txt.big.txt ...
# Loading model from cache /var/folders/9m/c2y7c9n93g72xbczzc8l40280000gn/T/jieba.u6b76574a6c9854ca9dfe84300984f1b9.cache
# Loading model cost 0.005 seconds.
# Prefix dict has been built succesfully.
# Counter({'\n': 25, '爲': 11, '問孝': 5, '其': 5, '以禮': 4, '人': 3, '哉': 3, '君子': 3, '問': 3, '知': 3, '不知': 3, '政': 3, '可知': 3, '道': 2, '吾': 2, '從': 2, '無違': 2, '樊遲': 2, '子': 2, '我': 2, '對曰': 2, '祭': 2, '以': 2, '孝乎': 2, '焉': 2, '廋': 2, '殆': 2, '子張': 2, '愼': 2, '言': 2, '餘': 2, '寡尤': 2, '則民服': 2, '無': 2, '損益': 2, '\ufeff': 1, '政以': 1, '德': 1, '譬如': 1, '北辰': 1, '居其': 1, '眾星': 1, '共': 1, '詩': 1, '三百': 1, '一言': 1, '以蔽': 1, '思': 1, '無邪': 1, '以政': 1, '齊之以': 1, '刑': 1, '民免': 1, '無恥': 1, '以德': 1, '齊': 1, '有恥且': 1, '格': 1, '十有': 1, '五而志': 1, '于學': 1, '三十': 1, '而立