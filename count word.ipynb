# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import jieba
import numpy as np
from collections import Counter

text = open('all.txt', "r",encoding="utf-8").read()  #讀文字資料
 
jieba.set_dictionary('dictionary/testname.txt')
with open('dictionary/stopword.txt', 'r', encoding='utf-8-sig') as f:  #設定停用詞
#with open('dictionary/stopWord_cloudmod.txt', 'r', encoding='utf-8-sig') as f:  #設定停用詞
    stops = f.read().split('\n')   
terms = []  #儲存字詞
for t in jieba.cut(text, cut_all=False):  #拆解句子為字詞
    if t not in stops:  #不是停用詞
        terms.append(t)

aword = '顏回'
bword = '顏淵'
cword = '子騫'
dword = '伯牛'
eword = '冉耕'
fword = '冉雍'
gword = '仲弓'
hword = '冉求'
iword = '冉有'
jword = '子有'
kword = '仲由'
lword = '子路'
mword = '宰我'
nword = '子我'
oword = '宰予'
pword = '端木賜'
qword = '子貢'
rword = '子游'
sword = '子夏'
tword = '子曰'


print('{}出現次數為'.format(aword))        
print(terms.count(aword))
print('{}出現次數為'.format(bword))        
print(terms.count(bword))
print('{}出現次數為'.format(cword))        
print(terms.count(cword))
print('{}出現次數為'.format(dword))        
print(terms.count(dword))
print('{}出現次數為'.format(eword))        
print(terms.count(eword))
print('{}出現次數為'.format(fword))        
print(terms.count(fword))
print('{}出現次數為'.format(gword))        
print(terms.count(gword))
print('{}出現次數為'.format(hword))        
print(terms.count(hword))
print('{}出現次數為'.format(iword))        
print(terms.count(iword))
print('{}出現次數為'.format(jword))        
print(terms.count(kword))
print('{}出現次數為'.format(lword))        
print(terms.count(lword))
print('{}出現次數為'.format(mword))        
print(terms.count(mword))
print('{}出現次數為'.format(nword))        
print(terms.count(nword))
print('{}出現次數為'.format(oword))        
print(terms.count(oword))
print('{}出現次數為'.format(pword))        
print(terms.count(pword))
print('{}出現次數為'.format(qword))        
print(terms.count(qword))
print('{}出現次數為'.format(rword))        
print(terms.count(rword))
print('{}出現次數為'.format(sword))        
print(terms.count(sword))
print('{}出現次數為'.format(tword))        
print(terms.count(tword))
#print('{}出現次數為'.format(cword))        
#print(terms.count(cword))
# Out:
# Building prefix dict from /Users/hongyining/testbot/dictionary/testname.txt ...
# Loading model from cache /var/folders/9m/c2y7c9n93g72xbczzc8l40280000gn/T/jieba.u992bd9ee20d47fb81fd85563bd91d0b8.cache
# Loading model cost 0.003 seconds.
# Prefix dict has been built succesfully.
# 顏回出現次數為
# 2
# 顏淵出現次數為
# 15
# 子騫出現次數為
# 5
# 伯牛出現次數為
# 2
# 冉耕出現次數為
# 0
# 冉雍出現次數為
# 0
# 仲弓出現次數為
# 7
# 冉求出現次數為
# 3
# 冉有出現次數為
# 11
# 子有出現次數為
# 3
# 子路出現次數為
# 47
# 宰我出現次數為
# 6
# 子我出現次數為
# 0
# 宰予出現次數為
# 1
# 端木賜出現次數為
# 0
# 子貢出現次數為
# 44
# 子游出現次數為
# 8
# 子夏出現次數為
# 25
# 子曰出現次數為
# 450
