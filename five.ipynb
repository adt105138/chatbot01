# %%
from PIL import Image
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import jieba
import numpy as np
from collections import Counter

text = open('one.txt', "r",encoding="utf-8").read()  #讀文字資料
 
jieba.set_dictionary('dictionary/dict.txt.big.txt')
with open('dictionary/stopword.txt', 'r', encoding='utf-8-sig') as f:  #設定停用詞
#with open('dictionary/stopWord_cloudmod.txt', 'r', encoding='utf-8-sig') as f:  #設定停用詞
    stops = f.read().split('\n')   
terms = []  #儲存字詞
for t in jieba.cut(text, cut_all=False):  #拆解句子為字詞
    if t not in stops:  #不是停用詞
        terms.append(t)
diction = Counter(terms)
# 可列印詞的統計數量
print(diction)

#font = "/Users/hongyining/Library/Fonts/Kaiu.ttf"  #設定字型(宋體)
font = "/System/Library/Fonts/PingFang.ttc"  #設定字型(宋體)
#wordcloud = WordCloud(font_path="C:\\Windows\\Fonts\\simsun.ttc")

#mask = np.array(Image.open("heart.png"))  #設定文字雲形狀 
#wordcloud = WordCloud(font_path=font) 
wordcloud = WordCloud(background_color="white", mask=mask , font_path=font)  #背景顏色預設黑色,改為白色,字體為宋體
wordcloud.generate_from_frequencies(diction)  #產生文字雲

#產生圖片
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

#wordcloud.to_file("/Users/hongyining/testbot/static/twenty.png")  #存檔
# Out:
# Building prefix dict from /Users/hongyining/testbot/dictionary/dict.txt.big.txt ...
# Loading model from cache /var/folders/9m/c2y7c9n93g72xbczzc8l40280000gn/T/jieba.u6b76574a6c9854ca9dfe84300984f1b9.cache
# Loading model cost 0.003 seconds.
# Prefix dict has been built succesfully.
# Counter({'\n': 18, '有': 5, '爲': 5, '於': 5, '君子': 4, '者': 4, '言': 4, '子貢': 4, '人': 3, '吾': 3, '夫子': 3, '和': 3, '其': 2, '孝弟': 2, '好': 2, '犯上': 2, '曾子': 2, '朋友': 2, '孝': 2, '事': 2, '已': 2, '愼': 2, '可謂': 2, '知': 2, '可': 2, '無': 2, '詩': 2, '\ufeff': 1, '學而': 1, '時習': 1, '說乎': 1, '有朋': 1, '自遠': 1, '方來': 1, '不亦樂乎': 1, '人不知': 1, '慍': 1, '乎': 1, '鮮矣': 1, '不好': 1, '作亂': 1, '未之有也': 1, '務本': 1, '本立': 1, '道生': 1, '仁之本': 1, '巧言令色': 1, '鮮': 1, '仁': 1, '日': 1, '三省': 1, '身': 1, '人謀': 1, '不忠乎': 1, '交而': 1, '信乎': 1, '傳不習乎': 1, '道': 1, '千乘之國': 1, '敬事': 1, '而信': 1, '節用': 1, '愛人': 1, '使民以時': 1, '弟子': 1, '入則': 1, '出則弟': 1, '謹而信': 1, '汎': 1, '愛眾': 1, '親仁': 1, '行有餘力': 1, '則以': 1, '學文': 1, '子夏': 1, '賢賢': 1, '易色': 1, '父母': 1, '能竭': 1, '其力': 1, '事君': 1, '能': 1, '致其身': 1, '交': 1, '信': 1, '雖': 1, '未學': 1, '必謂': 1, '之學': 1, '重則': 1, '不威': 1, '學則不固': 1, '主': 1, '忠信': 1, '無友': 1, '不如己': 1, '過則': 1, '勿憚': 1, '改': 1, '終': 1, '追遠': 1, '民德歸厚': 1, '子禽': 1, '問於': 1, '至': 1, '是': 1, '邦': 1, '必聞': 1, '其政': 1, '求': 1, '抑': 1, '溫': 1, '良': 1, '恭': 1, '儉': 1, '讓': 1, '以': 1, '得': 1, '之求': 1, '其諸': 1, '異乎': 1, '人之求': 1, '父在': 1, '觀其志': 1, '父沒觀': 1, '其行': 1, '三年': 1, '無改': 1, '父之道': 1, '禮之用': 1, '貴': 1, '先王': 1, '之道': 1, '斯': 1, '美': 1, '小大': 1, '由': 1, '所': 1, '不行': 1, '不以': 1, '禮節': 1, '可行': 1, '信近': 1, '義': 1, '復': 1, '恭近': 1, '於禮': 1, '遠': 1, '恥辱': 1, '因不失': 1, '其親': 1, '可宗': 1, '食無求': 1, '飽': 1, '居無求': 1, '安': 1, '敏': 1, '就': 1, '有道': 1, '正': 1, '焉': 1, '好學': 1, '也已': 1, '貧而': 1, '諂': 1, '富而': 1, '驕': 1, '何如': 1, '未若': 1, '貧而樂': 1, '富而好': 1, '禮者': 1, '云': 1, '如切如磋': 1, '如琢如磨': 1, '其斯之謂': 1, '賜': 1, '始可': 1, '吿': 1, '諸往': 1, '知來者': 1, '不患': 1, '不己': 1, '患不知': 1})
